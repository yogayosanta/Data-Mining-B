# %% [markdown]
# ## Data Integration

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv(r'C:\Users\ACER\Documents\Data Mining\Data-Mining-Class-master\Latihan\Data-Integration\Latihan\Data1.csv')
data1
# Out:
#    Kode Jenis Kelamin  Jam Belajar(jam)/hari
# 0     1     Perempuan                      3
# 1     2     Perempuan                      4
# 2     3     Laki-Laki                      3
# 3     4     Perempuan                      3
# 4     5     Laki-laki                      1
# 5     6     Laki-laki                      2
# 6     7     Laki-laki                      1
# 7     8     Perempuan                      2
# 8     9     Laki-laki                      2

# %%
data2 = pd.read_csv(r'C:\Users\ACER\Documents\Data Mining\Data-Mining-Class-master\Latihan\Data-Integration\Latihan\Data2.csv')
data2
# Out:
#    Kode  Nilai ETS  Nilai EAS
# 0     1         85         74
# 1     3         56         70
# 2     4         71         65
# 3     5         93         81
# 4     7         67         86
# 5     9         80         68
# 6    10         70         70
# 7    12         98         77

# %%
data = pd.merge(data1, data2, on = 'Kode')
data
# Out:
#    Kode Jenis Kelamin  Jam Belajar(jam)/hari  Nilai ETS  Nilai EAS
# 0     1     Perempuan                      3         85         74
# 1     3     Laki-Laki                      3         56         70
# 2     4     Perempuan                      3         71         65
# 3     5     Laki-laki                      1         93         81
# 4     7     Laki-laki                      1         67         86
# 5     9     Laki-laki                      2         80         68

# %%
data['Total Nilai'] = (data['Nilai ETS'] + data['Nilai EAS']) / 2
data
# Out:
#    Kode Jenis Kelamin  Jam Belajar(jam)/hari  Nilai ETS  Nilai EAS  \
# 0     1     Perempuan                      3         85         74
# 1     3     Laki-Laki                      3         56         70
# 2     4     Perempuan                      3         71         65
# 3     5     Laki-laki                      1         93         81
# 4     7     Laki-laki                      1         67         86
# 5     9     Laki-laki                      2         80         68
#
#    Total Nilai
# 0         79.5
# 1         63.0
# 2         68.0
# 3         87.0
# 4         76.5
# 5         74.0

# %%
delkol = data.drop(['Kode'], axis = 1)
delkol
# Out:
#   Jenis Kelamin  Jam Belajar(jam)/hari  Nilai ETS  Nilai EAS  Total Nilai
# 0     Perempuan                      3         85         74         79.5
# 1     Laki-Laki                      3         56         70         63.0
# 2     Perempuan                      3         71         65         68.0
# 3     Laki-laki                      1         93         81         87.0
# 4     Laki-laki                      1         67         86         76.5
# 5     Laki-laki                      2         80         68         74.0

# %%
delbar = data.drop([4])
delbar
# Out:
#    Kode Jenis Kelamin  Jam Belajar(jam)/hari  Nilai ETS  Nilai EAS  \
# 0     1     Perempuan                      3         85         74
# 1     3     Laki-Laki                      3         56         70
# 2     4     Perempuan                      3         71         65
# 3     5     Laki-laki                      1         93         81
# 5     9     Laki-laki                      2         80         68
#
#    Total Nilai
# 0         79.5
# 1         63.0
# 2         68.0
# 3         87.0
# 5         74.0
